# %%
pip install -U pynwb
# Out:
# Collecting pynwb
#   Downloading pynwb-2.8.3-py3-none-any.whl.metadata (8.9 kB)
# Collecting h5py>=2.10 (from pynwb)
#   Downloading h5py-3.11.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting hdmf>=3.14.5 (from pynwb)
#   Downloading hdmf-3.14.6-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: numpy>=1.18 in /home/dyuser-b/miniconda/envs/dynapse1/lib/python3.8/site-packages (from pynwb) (1.24.3)
# Requirement already satisfied: pandas>=1.1.5 in /home/dyuser-b/miniconda/envs/dynapse1/lib/python3.8/site-packages (from pynwb) (2.0.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/dyuser-b/miniconda/envs/dynapse1/lib/python3.8/site-packages (from pynwb) (2.9.0.post0)
# Requirement already satisfied: importlib-resources in /home/dyuser-b/miniconda/envs/dynapse1/lib/python3.8/site-packages (from hdmf>=3.14.5->pynwb) (6.4.0)
# Requirement already satisfied: jsonschema>=2.6.0 in /home/dyuser-b/miniconda/envs/dynapse1/lib/python3.8/site-packages (from hdmf>=3.14.5->pynwb) (4.23.0)
# Collecting ruamel-yaml>=0.16 (from hdmf>=3.14.5->pynwb)
#   Downloading ruamel.yaml-0.18.16-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: scipy>=1.4 in /home/dyuser-b/miniconda/envs/dynapse1/lib/python3.8/site-packages (from hdmf>=3.14.5->pynwb) (1.10.1)
# Requirement already satisfied: pytz>=2020.1 in /home/dyuser-b/miniconda/envs/dynapse1/lib/python3.8/site-packages (from pandas>=1.1.5->pynwb) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/dyuser-b/miniconda/envs/dynapse1/lib/python3.8/site-packages (from pandas>=1.1.5->pynwb) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/dyuser-b/miniconda/envs/dynapse1/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pynwb) (1.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/dyuser-b/miniconda/envs/dynapse1/lib/python3.8/site-packages (from jsonschema>=2.6.0->hdmf>=3.14.5->pynwb) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/dyuser-b/miniconda/envs/dynapse1/lib/python3.8/site-packages (from jsonschema>=2.6.0->hdmf>=3.14.5->pynwb) (2023.7.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/dyuser-b/miniconda/envs/dynapse1/lib/python3.8/site-packages (from jsonschema>=2.6.0->hdmf>=3.14.5->pynwb) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in /home/dyuser-b/miniconda/envs/dynapse1/lib/python3.8/site-packages (from jsonschema>=2.6.0->hdmf>=3.14.5->pynwb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/dyuser-b/miniconda/envs/dynapse1/lib/python3.8/site-packages (from jsonschema>=2.6.0->hdmf>=3.14.5->pynwb) (0.10.6)
# Requirement already satisfied: zipp>=3.1.0 in /home/dyuser-b/miniconda/envs/dynapse1/lib/python3.8/site-packages (from importlib-resources->hdmf>=3.14.5->pynwb) (3.20.2)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel-yaml>=0.16->hdmf>=3.14.5->pynwb)
#   Downloading ruamel.yaml.clib-0.2.8-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (2.2 kB)
# Downloading pynwb-2.8.3-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 23.3 MB/s eta 0:00:00
# Downloading h5py-3.11.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 43.2 MB/s eta 0:00:00
# Downloading hdmf-3.14.6-py3-none-any.whl (340 kB)
# Downloading ruamel.yaml-0.18.16-py3-none-any.whl (119 kB)
# Downloading ruamel.yaml.clib-0.2.8-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (596 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.0/596.0 kB 10.4 MB/s eta 0:00:00
# Installing collected packages: ruamel.yaml.clib, h5py, ruamel-yaml, hdmf, pynwb
# Successfully installed h5py-3.11.0 hdmf-3.14.6 pynwb-2.8.3 ruamel-yaml-0.18.16 ruamel.yaml.clib-0.2.8
# Note: you may need to restart the kernel to use updated packages.

# %%
import pynwb
import h5py
from pynwb import NWBHDF5IO

# %%
with NWBHDF5IO("sub-489_ses-20220708.nwb", "r") as io:
    read_nwbfile = io.read()
with NWBHDF5IO("sub-503_ses-20220902.nwb", "r") as io1:
    read_nwbfile1 = io1.read()
print("===Top-level fields===")
print(list(read_nwbfile.fields.keys()))
print(list(read_nwbfile1.fields.keys()))
# Out:
# ===Top-level fields===
# ['session_description', 'identifier', 'session_start_time', 'timestamps_reference_time', 'file_create_date', 'experimenter', 'acquisition', 'keywords', 'intervals', 'subject', 'trials', 'units', 'experiment_description', 'lab', 'institution', 'protocol']
# ['session_description', 'identifier', 'session_start_time', 'timestamps_reference_time', 'file_create_date', 'experimenter', 'acquisition', 'keywords', 'intervals', 'subject', 'trials', 'units', 'experiment_description', 'lab', 'institution', 'protocol']
